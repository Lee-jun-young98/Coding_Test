# %% [markdown]
# # 통계학
# - 수를 처리하는 것은 통계학에서 상당히 중요한 일
# - N은 홀수라고 가정
# 1. 산술평균 : N개의 수들의 합을 N으로 나눈 값
# 2. 중앙값 : N개의 수들을 증가하는 순서로 나열했을 경우 그 중앙에 위치하는 값
# 3. 최빈값 : N개의 수들 중 가장 많이 나타나는 값
# 4. 범위 : N개의 수들 중 최대값과 최솟값의 차이

# %%
n = int(input())
array = [int(input()) for _ in range(n)]
# Out:
# 5
# 1
# 3
# 8
# -2
# 2

# %%
def statics_program(array):
    array.sort()
    average = round(sum(array) / n)
    median_index = (len(array)-1/2)
    median = array[median_index]
    mode_array = [0 for _ in range(0,8000)] 
    for i in range(len(array)):
        mode_array[array[i]]  

    number_range = max(array) - min(array)

# %%
array.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-de5b83cd1dae> in <module>
# ----> 1 array.count()
#
# TypeError: count() takes exactly one argument (0 given)
