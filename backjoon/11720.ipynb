# %%
n = int(input())
array = [list(map(int, input()))]
print([sum(i) for i in array][0])
# Out:
# 25
# 7000000000000000000000000000
# 7

# %%
n = int(input())
print(sum(map(int, input())))
# Out:
# 5
# 5
