# %%
a = int(input())
b = int(input())
c = int(input())

new_number = a * b * c
array = list(map(int, str(new_number)))
count_array = [0 for i in range(10)]
for i in array:
    count_array[i] += 1

for i in count_array:
    print(i)
# Out:
# 150
# 266
# 427

# %%
d = input
a = int(d()) * int(d()) * int(d())
for j in range(10):
    print(str(a).count(str(j)))
# Out:
# 150
# 266
# 427
# 3
# 1
# 0
# 2
# 0
# 0
# 0
# 2
# 0
# 0
